# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %%
initial_url = 'https://www.tripadvisor.com/Attraction_Products-g187497-a_sort.-Barcelona_Catalonia.html#ATTRACTION_LIST'

# %% [markdown]
# ## Combining all the pages in one list:

# %%
# Generating a list "urls" of all the pages of the website: 

next_url = initial_url
urls = next_url
urls = []

while next_url != 0:
    soup = BeautifulSoup(requests.get(next_url).content, "lxml")
    urls.append(requests.get(next_url).url)
    try:
        next_url = "https://www.tripadvisor.com" + soup.select("a.nav.next.rndBtn.ui_button.primary.taLnk")[0]["href"]
    except:
        next_url = 0

# %%
len(urls)
# Out:
# 43

# %%
def get_info(soup):    
    """ Returns a list of the titles of all the tours on each page as well as their price"""
  
    
    tours_prices = []
    
    samples1 = soup.find_all("div", {"class":"listing_title"})
    samples2 = soup.find_all("div", {"class":"from"})
    for s1, s2 in zip(samples1, samples2):
            

              tours_prices.append([s1.text, s2.text])
    
    return(tours_prices) 
    
    

def parse_tours(url):
    """ Fetches a TripAdvisor webpage and extracts information: """
    
    r = requests.get(url)
    c = r.content
    
    # Parsing the HTML: 
    soup = BeautifulSoup(c, "lxml")
    
    # Using our get_info function to extract the information we want:
    
    info = get_info(soup)
    return(info)

# %% [markdown]
# ## Scraping Synchronously:

# %%
# We loop through the urls list, processing one at a time, and extracting our information:

start = time.time()
results = []
for u in urls:
    results.append(parse_tours(u))
end = time.time()
print("Time Taken: {:.6f}s".format(end-start))    

# On my PC usually takes between 60 and 80 seconds.
# Out:
# Time Taken: 63.567342s

# %%
print(results)
# Out:
# [[['Basilica of the Sagrada Familia Admission Ticket', 'from €15.00* '], ["Gaudi's Casa Batlló Admission Ticket with Video Tour", 'from €24.50* '], ['City Sightseeing Barcelona Hop-On Hop-Off Tour', 'from €30.00* '], ['Priority Access: Barcelona Sagrada Familia Tour', 'from €38.00* '], ['Montserrat Tour from Barcelona Including Lunch and Wine Tasting in...', 'from €94.95* '], ['Montserrat and Oller del Mas Winery Tour from Barcelona', 'from €67.95* '], ['Park Guell Admission Ticket', 'from €9.00* '], ['Barcelona City Tour Hop-On Hop-Off', 'from €30.00* '], ['Flamenco Night at Tablao Cordobes', 'from €44.00* '], ['Camp Nou Experience and Museum Admission Ticket', 'from €28.50* '], ['Skip the Line: Gaudi’s La Pedrera Audio Tour in Barcelona', 'from €22.00* '], ['Tapas and Wine Experience Small-Group Walking Tour', 'from €75.00* '], ['Flamenco Show at Los Tarantos Barcelona', 'from €15.00* '], ['Sagrada Familia Official Guided Tour - Priority Access', 'from €35.00* '], ['Interactive Spanish Cooking Experience in Barcelona', 'from €32.00* '], ['Girona and Costa Brava Tour from Barcelona', 'from €89.00* '], ["Skip the Line Guided Walking Tour: Gaudi's Park Guell in Barcelona", 'from €21.60* '], ['Montserrat Tour with Tapas and Wine from Barcelona', 'from €77.95* '], ['Barcelona Half-Day Bike Tour', 'from €26.00* '], ['Basilica of the Sagrada Familia Admission Ticket with Tower Access', 'from €29.00* '], ['Three Countries in One Day: France, Andorra and Spain from Barcelona', 'from €129.00* '], ['Tapas Evening Walking Tour of Barcelona', 'from €70.00* '], ['Flamenco Show at Barcelona City Hall', 'from €15.00* '], ['Priority Access: Best of Barcelona Tour Including Sagrada Familia', 'from €89.00* '], ['Barcelona Gothic Quarter Morning Walking Tour', 'from €16.00* '], ['Early Access to Sagrada Familia with Optional Tower Access', 'from €42.80* '], ['Skip the Line: Barcelona Palau de la Música Catalana Tour', 'from €20.00* '], ['Ebike Tour with Cable Car Ride and Boat Cruise Barcelona Premium...', 'from €49.50* '], ['Sagrada Familia Guided Tour with Towers Access', 'from €57.90* '], ['Flamenco Evening Show at Tablao de Carmen with Dinner or Drink', 'from €43.00* ']], [['Teleferic de Montjuic Admission Ticket', 'from €12.70* '], ["Gaudi's Casa Batlló Fast-Track Ticket with Audio Guide", 'from €29.50* '], ['Early Access to Montserrat Monastery from Barcelona', 'from €25.80* '], ['Small-Group Barcelona Cooking Class', 'from €65.00* '], ['Girona and Costa Brava Small-Group Tour with Hotel Pick-Up', 'from €95.00* '], ['Helicopter Flight, Walking Tour and Boat Cruise Barcelona Premium...', 'from €99.50* '], ['Girona, Figueres, and Dali Museum Day Trip from Barcelona', 'from €79.00* '], ['Basilica of the Sagrada Familia Admission Ticket with Audio Guide', 'from €22.00* '], ['Flamenco Performance at Teatre Poliorama or Palau de la Música...', 'from €35.00* '], ['Sagrada Familia: Fast Track Guided Tour with Towers Access', 'from €47.50* '], ['Small-Group Medieval Villages Day Trip from Barcelona', 'from €89.00* '], ['Barcelona Electric Bike Tour with Tapas and Drinks', 'from €59.00* '], ['Priority Access: Barcelona Sagrada Familia Tour with Optional Tower...', 'from €38.00* '], ['Montserrat Monastery Tour from Barcelona Including Cogwheel Train Ride', 'from €55.00* '], ['Barcelona Segway Tour', 'from €49.00* '], ['Penedes Wineries Small Group Tour with Wine, Cava and Tapas Tasting', 'from €66.56* '], ['Skip the Line: Park Güell and La Sagrada Familia Tour in Barcelona', 'from €72.00* '], ['Basilica of Santa Maria del Mar Admission Ticket and Rooftop Visit', 'from €8.00* '], ['Spanish Guitar Concert at the Palau de la Música Catalana in Barcelona', 'from €39.00* '], ['bar crawl barcelona', 'from €13.20* '], ['Montserrat Monastery and Natural Park Hiking Premium Small Group Tour...', 'from €66.00* '], ['Original bike tour in English', 'from €24.00* '], ['Salvador Dali Museum, Figueres, and Cadaques Small-Group Day Trip...', 'from €95.00* '], ['Pi ...

# %% [markdown]
# ## Scraping Asynchronously using ProcessPool:

# %%
# Here we have 4 workers, they are our "executor". Each of them will execute the parse_tours function 
# against a url.
# All tasks will be executed in some time in the future (i.e. not immediately).
# The as_completed function watches our future_results for completion,
# after which we'll be able to fetch each result via the result method.

# This method is fast, because we can submit a task while other tasks are still in progress,
# there is no waiting. This is why this process is asynchronous.


from concurrent.futures import ProcessPoolExecutor
import concurrent.futures
start = time.time()


with ProcessPoolExecutor(max_workers = 4) as executor:
    future_results = {executor.submit(parse_tours, url): url for url in urls}


results2 = []
for future in concurrent.futures.as_completed(future_results):
        results2.append(future.result())
end = time.time()
print("Time Taken: {:.6f}s".format(end-start))

# Usually takes about 17 seconds on my PC - between 4 and 5 times faster compared to the synchronous code.
# Out:
# Time Taken: 16.728733s

# %%
results2
# Out:
# [[['Exclusive sailing boat 2h', 'from €299.00* '],
#   ['Shore Excursion: Girona Pals and Peratallada Medieval Towns from...',
#    'from €117.00* '],
#   ['Private Full Day City Tour in Barcelona', 'from €79.00* '],
#   ['Shore Excursion: Montserrat Abbey and Salnitre Caverns from Barcelona',
#    'from €117.00* '],
#   ['Poble Espanyol Private Tour in Barcelona', 'from €95.00* '],
#   ['Barcelona Shore Excursion: Medieval Costa Brava from Barcelona',
#    'from €117.00* '],
#   ['4 hour Shore Excursion to Santa Severa Castle from Civitavecchia',
#    'from €109.00* '],
#   ['La Roca Village Private Experience with Hotel Pick-up', 'from €91.00* '],
#   ['Barcelona City Tapas Tour by Vespa Scooter', 'from €125.00* '],
#   ['Chocolate Walking Private Tour in Barcelona', 'from €29.00* '],
#   ['Sitges Private Tour from Barcelona', 'from €59.00* '],
#   ['Private Half Day Walking Tour in Barcelona', 'from €31.00* '],
#   ['Private Half Day City Tour in Barcelona', 'from €70.00* '],
#   ['Private Las Ramblas Walking Tour and Iberian Ham Experience in...',
#    'from €65.00* '],
#   ['Private Half Day Walking City Tour in Barcelona', 'from €48.00* '],
#   ['Private Full Day Walking City Tour in Barcelona', 'from €130.00* '],
#   ['Private Modern Architecture Tour of Barcelona', 'from €56.00* '],
#   ['E-Bike Private Tour: Explore Barcelona', 'from €95.00* '],
#   ['Sagrada Familia Facades Private Gay Tour', 'from €39.00* '],
#   ['Florence Private Tour For Kids', 'from €113.00* '],
#   ['Jewish Quarter of Barcelona Private Gay Tour', 'from €45.00* '],
#   ['Montserrat Guided Tour with Flamenco Show', 'from €75.00* '],
#   ['Highlights of Barcelona: Full-Day Private Gay Tour', 'from €239.00* '],
#   ['A Taste Of The Vatican And The Market', 'from €142.00* '],
#   ['Gay Friendly Private Tour Girona: a Game of Thrones City with Lunch',
#    'from €249.00* '],
#   ['Barcelona Highlights Private Gay Tour from Port to Port',
#    'from €239.00* '],
#   ['Skip the Line Gaudi Masterpieces in One Day with Flamenco Show',
#    'from €199.00* '],
#   ['Heli-Skiing in Andorra', 'from €333.00* '],
#   ['Montserrat Monastery & Wineries - Private tour', 'from €325.00* '],
#   ["The Secrets of Barcelona's Old Town", 'from €22.00* ']],
#  [['Barcelona Torre Bellesguard Entrance Ticket Including Audio Guide and...',
#    'from €13.00* '],
#   ['Guided Walking Tour With Tapas Lunch', 'from €20.00* '],
#   ['Barcelona Beer Bike Tour', 'from €25.00* '],
#   ['Hash Marihuana Hemp Museum Audio Tour in Barcelona', 'from €9.00* '],
#   ['Catalonia in Miniature Theme Park Ticket', 'from €13.50* '],
#   ['6-Day Spain Tour from Barcelona: Zaragoza, Madrid, Cordoba, Seville...',
#    'from €767.00* '],
#   ['5-Day Spain Tour: Cordoba, Seville, Granada and Toledo from Barcelona',
#    'from €515.26* '],
#   ['Barcelona Shore Excursion: Best of Barcelona Small-Group Tour - Skip...',
#    'from €89.00* '],
#   ['Sunrise Vatican Private Tour', 'from €108.00* '],
#   ['Gaudì Private Tour with Skip the Line Sagrada Familia Entry in...',
#    'from €112.00* '],
#   ['Montserrat and Sitges Easy Hike with Hotel Pickup from Barcelona',
#    'from €75.60* '],
#   ['Private Barcelona Tour with Skip-The-Line Park Güell and Sagrada...',
#    'from €140.00* '],
#   ['Sagrada Familia and Park Guell Private Guided Family Tour in Barcelona',
#    'from €94.00* '],
#   ['Park Guell and Sagrada Familia Tour in Barcelona', 'from €68.56* '],
#   ['Customizable 4-Hour Private Tour of Madrid with Chauffeur',
#    'from €100.00* '],
#   ['Private Montserrat Tour in Barcelona with Hotel Pick-up', 'from €90.00* '],
#   ['Private E-Bike Tour: 5 Barcelona Neighborhoods', 'from €38.00* '],
#   ['Full Day Guided Tour & Skip the Line: Sagrada Familia, Park Güell and...',
#    'from €160.00* '],
#   ['Barcelona Private Luxury Yacht Tour', 'from €499.00* '],
#   ['Barcelona Private 4-Hour Guided Tour', 'from €250.00* '],
#   ['Private Tour: Medieval Costa Brava from Barcelona', 'from €117.00* '],
#   ['Private 12-Hour Tour of Tangier from Malaga or Marbella',
#    'from €190.00* '],
#   ['The Gaudí Homes: Casa Batlló & Casa Milà Combination Tour',
#    'from €99.00* '],
#   ['Private Day Trip to Segovia from Madrid', 'from €79.00* '],
#   ['Private Tour Sagrada Familia & Park Guell', 'from €100.00* '],
#   ['Private Shore excursion of Barcelona with Skip the Line Sagrada...',
#    'from €180.00* '],
#   ['Private Transfer to Kennedy Space Museum from Miami', 'from €185.00* '],
#   ['Sagrada Familia Express Private Guided Tour', 'from €65.00* '],
#   ['Montserrat and Cava Trail Private Day Trip from Barcelona',
#    'from €110.00* '],
#   ['Cardona and Salt Mountain Cultural Park Small Group Tour with Hotel...',
#    'from €95.00* ']],
#  [['Private Tour of Zaragoza', 'from €45.00* '],
#   ['Private 3-Hour Walking Tour of Florence with entrance to Accademia...',
#    'from €50.00* '],
#   ['Private Official Guide to Visit Alhambra in Granada', 'from €65.00* '],
#   ['Highlights of Barcelona: Full-Day Private Tour with Lunch',
#    'from €239.00* '],
#   ['Barcelona Night Segway Group Tour', 'from €49.00* '],
#   ['La Garrotxa Volcanic Zone Natural Park Hiking and Besalú medieval town',
#    'from €129.00* '],
#   ['Costa Brava Coast Path Hiking and Tossa de Mar', 'from €129.00* '],
#   ['Collsacabra Cliffs Hiking and Rupit medieval town', 'from €129.00* '],
#   ['Madrid Guided Private Tour: Prado, Thyssen-Bornemisza or Reina Sofia...',
#    'from €59.00* '],
#   ['6-Hour Private tour of Girona from Barcelona', 'from €100.00* '],
#   ['Private One-Way Transfer To or From Madrid Airport', 'from €19.00* '],
#   ['Vespa Scooter GPS Guided 6-hour Tour in Barcelona', 'from €45.00* '],
#   ['Private Tour: Barcelona Sailing Trip', 'from €48.57* '],
#   ['Small-Group Sailing Lesson in Barcelona', 'from €79.00* '],
#   ['Private Oil Tasting Tour', 'from €95.00* '],
#   ['Erotic Museum Admission Ticket with Marilyn Monroe TOUR', 'from €18.67* '],
#   ['Penedes Region Wine and Food Tour with Transport from Barcelona',
#    'from €168.00* '],
#   ['Private walking tour of Lisbon', 'from €27.00* '],
#   ['Private full day tour of Fatima from Lisbon', 'from €74.00* '],
#   ['Private Car Highlights Tour of Barcelona', 'from €55.00* '],
#   ['Private Barcelona Exclusive Tour by Minibus and Personal expert guide',
#    'from €125.00* '],
#   ['VR Virtual Reality Walking Tour', 'from €39.00* '],
#   ['Sagrada Familia 2 hours Segway tour', 'from €59.00* '],
#   ['8-Hour Private The Best of the Basque Coast - The Game of Thrones...',
#    'from €130.00* '],
#   ['Barcelona Vintage Photo Tour With a Polaroid Camera', 'from €55.00* '],
#   ['Barcelona Motorboat Tour including Water Toys', 'from €450.00* '],
#   ['Private Sailing Tour with Lesson in Barcelona', 'from €57.00* '],
#   ['Private 2 hour Sailing trip including skipper', 'from €249.00* '],
#   ['Grand Montjuic Private Segway Tour', 'from €89.00* '],
#   ['Barcelona Romantic Sailing&Night Experience', 'from €325.00* ']],
#  [['The Ancient Churches of Montserrat Mountain Tour by Tebes Trail',
#    'from €80.00* '],
#   ['Small Group Sagrada Familia with Historian', 'from €120.30* '],
#   ['Private Insider Introduction to Barcelona', 'from €286.00* '],
#   ['Private Medieval Day Trip to Girona with a Local', 'from €78.00* '],
#   ['7-Day Spain Tour: Galicia and north of Portugal from Barcelona',
#    'from €865.34* '],
#   ['A Guided Walking Tour of the Sagrada Familia and Barrio Gotico',
#    'from €45.00* '],
#   ['Private Shore Excursion in Barcelona', 'from €180.00* '],
#   ['Private Taste of Barcelona', 'from €107.00* '],
#   ['Transfer from Barcelona to Port Aventura Park', 'from €350.00* '],
#   ['Private Barcelona Airport Shuttle Transfer: Departure', 'from €260.00* '],
#   ['Day Trip to Siena and San Gimignano With Wine Tasting', 'from €276.00* '],
#   ['Private Tour of Vatican by night', 'from €85.00* '],
#   ['Small Group: Montserrat Monasteries with Brunch from Barcelona',
#    'from €89.00* '],
#   ['Private Day Trip to the Lively Seaside Town of Sitges', 'from €34.00* '],
#   ['Discover Gaudi Small Group Kids Tour', 'from €80.00* '],
#   ['Picasso Museum and Gothic Quarter small group Tour', 'from €110.00* '],
#   ['Outdoor walking tour of Sagrada Familia and Gothic Quarter',
#    'from €90.00* '],
#   ['Private Wine Tour to Priorat for wine lovers from Barcelona Sitges...',
#    'from €199.00* '],
#   ['Private Wine & Food Tour with Traditional Farmers Market by...',
#    'from €173.00* '],
#   ['Private Prestige Wine Tour with lunch in a Michelin Star Restaurant...',
#    'from €265.00* '],
#   ['Barcelona Montserrat and Segway Winery Private Tour with Wine and...',
#    'from €195.00* '],
#   ['Córdoba Private Guided Day Tour from Madrid', 'from €275.00* '],
#   ['GoCar Barcelona Experience', 'from €45.00* '],
#   ['Sagrada Familia guided tour and La Pedrera entrance premium Edit',
#    'from €65.00* '],
#   ['Banana Boat Experience', 'from €25.00* '],
#   ['Park Güell Photo Shoot Tour', 'from €70.00* '],
#   ['Private 4-Hour Tour of Naples with private driver and official tour...',
#    'from €60.00* '],
#   ['Dating bike tour', 'from €89.00* '],
#   ['Madrid Private 4-Hour Tour of Thyssen-Bornemisya and Reina Sofia...',
#    'from €90.00* '],
#   ['Private Custom Day Trip to Toledo from Madrid', 'from €79.00* ']],
#  [['Tours and BMC rental bikes in Barcelona', 'from €85.00* '],
#   ['CYCLING THROUGH THE VINEYARDS (THE SUSTAINABLE VISIT)', 'from €42.00* '],
#   ['NADAL & MEHARI BETWEEN VINEYARDS', 'from €65.00* '],
#   ['Andorra:Trekking and Gastronomy Premium Small Group Experience',
#    'from €330.00* '],
#   ['Barcelona 3-hour Private Segway Tour', 'from €150.00* '],
#   ['Private Sailing & Wine Tasting Tour', 'from €300.00* '],
#   ['Sailing Tour, Water Sports Multi-Activities & Lunch', 'from €145.00* '],
#   ['Private Madrid Walking Tour: Famous Retiro Park', 'from €29.00* '],
#   ['Walking Tour of Malaga with entrance to Picasso and or Thyssen Museums',
#    'from €49.00* '],
#   ['Private Madrid Walking Tour: Famous Royal Palace', 'from €38.00* '],
#   ['Water Sports Multi-Activities & Lunch', 'from €95.00* '],
#   ['Walking Tour of Malaga with entrance to the Cathedral', 'from €49.00* '],
#   ['Private Arrival Transfer from Paris Charles de Gaulle airport to City...',
#    'from €91.00* '],
#   ['Private 4-hour Tour of Mijas from Malaga or Marbella', 'from €90.00* '],
#   ['2,5 Hour Private Guided Tapas Walking Tour in Seville', 'from €99.00* '],
#   ['3-Hour Private Guided Walking Tour of Triana', 'from €48.00* '],
#   ['Skip the Line: La Casa de la Seda Guided Tour in Barcelona',
#    'from €6.90* '],
#   ['4-Hour Private Guided Walking Tour: Palaces of Seville', 'from €80.00* '],
#   ['Half day trip to Santa Severa Castle - Private', 'from €99.00* '],
#   ['Chicken Boat', 'from €35.00* '],
#   ['Luxury Motor Yacht', 'from €640.00* '],
#   ['Grand Barcelona Segway Tour - 180 min', 'from €65.00* '],
#   ['FLYFISH ADVENTURE', 'from €30.00* '],
#   ['PREMIUM YACHT', 'from €800.00* '],
#   ['Private Guided City Tour of Cordoba', 'from €45.00* '],
#   ['Authentic sunset sailing with exclusive cava aperitif', 'from €69.00* '],
#   ['Private Full-Day Tour of Ronda from Marbella', 'from €99.00* '],
#   ['City Beaches & El Poblenou: Private Bike Tour', 'from €23.00* '],
#   ['Barcelona Airport Transfer To Costa Brava: Blanes- Lloret de Mar...',
#    'from €450.00* '],
#   ['Barcelona eBike Tour with Skip-the-Line Access to Sagrada Familia',
#    'from €120.00* ']],
#  [['Barcelona Sagrada Familia and Montserrat Small Group Tour with Hotel...',
#    'from €95.00* '],
#   ['Barcelona City Highlights Shore Excursion Tour and Skip-the-Line at...',
#    'from €66.00* '],
#   ['Barcelona E-Bike Photography Tour', 'from €65.00* '],
#   ['Sagrada Familia and Park Guell Skip the Line, La Pedrera and Casa...',
#    'from €77.00* '],
#   ['Football Club Barcelona Private Tour', 'from €109.00* '],
#   ['Costa Brava Full Day Trip from Barcelona', 'from €84.00* '],
#   ['Sagrada Família Guided Tour', 'from €37.00* '],
#   ['Private Arrival Transfer from El Prat Airport to Central Barcelona',
#    'from €13.34* '],
#   ['Tapas Like a Local: Sant Antoni Neighborhood Tapas Tour', 'from €69.00* '],
#   ['Mediterranean Sea Sailing Trip from Barcelona', 'from €67.50* '],
#   ['Barcelona Old Town and Gothic Quarter Walking Tour', 'from €16.00* '],
#   ['Museum of Illusions Barcelona Admission Ticket', 'from €10.00* '],
#   ['2-Hour Colosseum Express Tour with Arena Stage Visit', 'from €48.00* '],
#   ['Horseback Riding Tour in Natural Park from Barcelona', 'from €99.00* '],
#   ["Walking History Tour of Barcelona's Jewish Quarter", 'from €135.00* '],
#   ['Ebike Tour with Skip the Line Sagrada Familia Barcelona Premium Small...',
#    'from €49.50* '],
#   ['Small-Group Sail Trip from Barcelona Port and Paddle Boarding',
#    'from €70.00* '],
#   ['Barcelona 3-Hour Segway Tour', 'from €70.00* '],
#   ['Tibidabo Amusement Park Entrance Ticket in Barcelona', 'from €28.50* '],
#   ['Sightseeing Segway Tour in Barcelona', 'from €29.00* '],
#   ['Port Vell and Barcelona Skyline Catamaran Cruise', 'from €7.50* '],
#   ['Sant Pau Recinte Modernista Entrance Ticket in Barcelona',
#    'from €14.00* '],
#   ['Dali Museum Day Trip from Barcelona by High-Speed Train with Optional...',
#    'from €109.00* '],
#   ['The Montserrat and Codorniu Wine Cellars Tour in Barcelona',
#    'from €74.00* '],
#   ['Costa Brava 8-hour Trip from Barcelona', 'from €55.00* '],
#   ['The Barcelona Pass: Entry to Over 20 Attractions', 'from €109.00* '],
#   ['La Sagrada Familia and Skip-the-Line Entry to Park Guell',
#    'from €38.40* '],
#   ['Early Access:The Awakening of La Pedrera Small-Group Tour',
#    'from €39.00* '],
#   ['Wonderful green Retiro Park 90 minutes', 'from €29.00* '],
#   ['Barcelona Modernism and Gaudi Walking Tour', 'from €16.00* ']],
#  [['E-BIKE TOUR HIGHLIGHTS OF BARCELONA - MONTJUIC VIEWS', 'from €34.00* '],
#   ['Pyrenees Hiking from Barcelona', 'from €150.00* '],
#   ["Grandma's Cooking Barcelona: A Hands-On Cooking Experience",
#    'from €85.00* '],
#   ['4-Hour Guided Bike Tour in Barcelona', 'from €35.00* '],
#   ['Barcelona Boat Party', 'from €49.50* '],
#   ['1.5-Hour Sights of Barcelona E-Bike Tour Led by a Local Guide',
#    'from €27.00* '],
#   ['Small-Group Barcelona Sailing Trip', 'from €79.00* '],
#   ['Requesens Palace Dinner Experience with Medieval Show', 'from €71.00* '],
#   ['2.5-Hour Private Guided Family Dragon Tour in Barcelona',
#    'from €129.00* '],
#   ['Barcelona Private Bike Tour', 'from €24.00* '],
#   ['Casa Vicens and Park Güell Tour in Barcelona', 'from €59.00* '],
#   ['Barcelona Night Card: Nightlife and Club Pass', 'from €20.00* '],
#   ['Discovery Family Tour in Barcelona', 'from €129.00* '],
#   ['Bike & Paella Tour', 'from €58.00* '],
#   ['Barcelona Mosaic Classes', 'from €90.00* '],
#   ['Temple of Debod and City center 1 Hour', 'from €19.00* '],
#   ['Barcelona Photography Tour', 'from €50.00* '],
#   ['Photography Walk Through London', 'from €80.00* '],
#   ['Illa Fantasia Water and Theme Park Tickets with Shuttle', 'from €28.00* '],
#   ['Barcelona Bike Tour Including Tapas Lunch', 'from €45.00* '],
#   ['Barcelona Beer Tasting and Brewery Tour', 'from €29.00* '],
#   ['Barcelona Guided Bike Tour', 'from €24.00* '],
#   ['Barcelona City Tour by Vespa Scooter', 'from €80.00* '],
#   ['Casa de les Punxes Direct Entry in Barcelona', 'from €12.50* '],
#   ['Private Street Art Bike Tour in Barcelona', 'from €14.00* '],
#   ['3-Hour Barcelona E-Bike Tour', 'from €35.00* '],
#   ['Erotic Museum Walking Guided Tour in Barcelona', 'from €33.40* '],
#   ['Guitarra y Flamenco', 'from €35.00* '],
#   ['Dragon Family Tour in Barcelona', 'from €15.00* '],
#   ['Nadal de la Boadella Estate Cava Sensations Tour', 'from €22.00* ']],
#  [['Luxury Yacht Tour with Professional Skipper and Tapas Menu from...',
#    'from €381.25* '],
#   ['Tibidabo Mountain Private Gay Tour', 'from €179.00* '],
#   ['Full-Day Private Tour: Girona and Costa Brava With Lunch',
#    'from €200.00* '],
#   ['Full Day Guided Tour: Girona & Costa Brava Plus Lunch', 'from €160.00* '],
#   ['Team building Barcelona: Create the logo of your company',
#    'from €560.00* '],
#   ['Private tour of Barcelona and La Roca Village with driver and guide',
#    'from €81.00* '],
#   ['Private walking tour of Avila with professional tour guide',
#    'from €27.00* '],
#   ['Private Walking Tour of Zaragoza', 'from €31.00* '],
#   ['Private Family Experience - Dragon Tour in Barcelona', 'from €49.75* '],
#   ['Private Luxury Yacht 3-Hour Charter From Barcelona', 'from €395.00* '],
#   ['Private tour of Madrid and Las Rozas Village with driver and guide',
#    'from €70.00* '],
#   ['Private tour of Ronda and winery from Malaga', 'from €89.00* '],
#   ['Private full day tour of Toledo and Segovia from Madrid',
#    'from €110.00* '],
#   ['Human Tower Tour with Food and Wine Tasting in Barcelona',
#    'from €79.00* '],
#   ['3 or 6 hour Private Guided Walking tour in Toledo', 'from €45.00* '],
#   ['Wine and Cava Tasting and Human Tower Festival from Barcelona',
#    'from €85.00* '],
#   ['Barcelona Gothic Quarter Walking Tour and Cooking Workshop',
#    'from €85.00* '],
#   ['Girona and Wineries of Perelada Private Tour from Barcelona',
#    'from €250.00* '],
#   ['2,000 Years in a Tour', 'from €45.00* '],
#   ['Private Barcelona Balloon 2 Pax including Breakfast in Restaurant and...',
#    'from €335.00* '],
#   ['Exclusive Ballooning Barcelona Including Typical Breakfast in...',
#    'from €300.00* '],
#   ['Traditional Balloon Rides from Barcelona Including Breakfast in...',
#    'from €160.00* '],
#   ['7 Days of Riding the Classic Climbs of the TDF Tour 2018',
#    'from €2,345.00* '],
#   ['Guided Tour with glass of cava and live sword show at Requesens Palace',
#    'from €17.00* '],
#   ['Private Barcelona Food Lovers Walking Tour', 'from €138.00* '],
#   ['Barcelona Guided Segway 3-hour Tour', 'from €69.00* '],
#   ['Private Arrival or Departure Transfer: Girona Airport to Barcelona',
#    'from €37.10* '],
#   ['Barcelona Private Sailing Tour', 'from €199.00* '],
#   ['5 Day Pyrenees Spring Safari Adventure for Families', 'from €1,335.00* '],
#   ['Champagne Sunset Boat Party in Barcelona', 'from €40.00* ']],
#  [['Highlights of Barcelona Private Experience Port to port',
#    'from €239.00* '],
#   ['Private Pyrenees Jeep Safari Day Tour from Barcelona', 'from €199.00* '],
#   ['Private Sailing Experience With Skipper in Barcelona', 'from €360.00* '],
#   ['Small Group Outdoors Walking Tour of Sagrada Familia and Gothic...',
#    'from €90.00* '],
#   ['Small Group walking Tour of Gothic District and Picasso Museum',
#    'from €110.00* '],
#   ['Sagrada Familia Semi-Private Tour', 'from €100.00* '],
#   ['1-hour Private Speedboat Cruise from Barcelona', 'from €250.00* '],
#   ['Private Round Transfer to Park Guell from Barcelona Center',
#    'from €11.40* '],
#   ['Private Motor Cruiser Adventure', 'from €399.00* '],
#   ['High Speed Motor Cruiser Adventure', 'from €99.00* '],
#   ['Barcelona Highlights and Montserrat with Cogwheel Train Guided Day...',
#    'from €108.00* '],
#   ['Private Barcelona Transfer: Harbor Arrivals to Airport', 'from €280.00* '],
#   ['PRIORAT PRIVATE WINE TOUR', 'from €200.00* '],
#   ['Private Barcelona Transfer: from the City to Harbor', 'from €270.00* '],
#   ['Private Barcelona Transfer: Airport Arrivals to Harbor', 'from €280.00* '],
#   ['Private Barcelona Transfer: Harbor Arrivals to the City',
#    'from €270.00* '],
#   ['Explore hidden streets with a guide', 'from €25.00* '],
#   ['Exclusive Ballooning Barcelona', 'from €1,300.00* '],
#   ['Private Walking Tour, Wine Tasting & Tapas Dinner', 'from €150.00* '],
#   ['Barcelona Walking Tour, Wine Tasting & Tapas Dinner', 'from €110.00* '],
#   ['Day Trip to Pompeii and Amalfi Coast from Naples Cruise Port',
#    'from €160.00* '],
#   ['Orvieto and Assist Day Trip from Rome', 'from €235.00* '],
#   ['Combined Tour of the Colosseum and Market', 'from €130.00* '],
#   ["Barcelona's ultimate Luxury Yacht experience", 'from €2,599.00* '],
#   ['One Day Tour of Rome', 'from €186.00* '],
#   ['Day Trip to Florence and Pisa from Livorno Cruise Port', 'from €260.00* '],
#   ['Barcelona Gran Turismo Car Driving & Cooltural Experience',
#    'from €799.00* '],
#   ['Private Walking Tour of Ancient Ostia', 'from €48.00* '],
#   ['Adrenalin Pack Experience From Salta', 'from €96.20* '],
#   ['Semi-Private Tour of the Sagrada Familia', 'from €100.00* ']],
#  [['Arrival Sightseeing Tour from Barcelona Airport or Harbour',
#    'from €249.00* '],
#   ['Sailing Experience and Sagrada Familia with Tower Access',
#    'from €90.00* '],
#   ['Forum Beach eScooter Tour', 'from €35.00* '],
#   ['Gaudí Segway Tour', 'from €57.00* '],
#   ['Barcelona Night Tapas Tour with Flamenco Show', 'from €109.00* '],
#   ['Barcelona Private Sailing Half-Day from Port Vell', 'from €569.00* '],
#   ['Barcelona Private Sailing Tour at Sunset', 'from €399.00* '],
#   ['Monestir de Pedralbes Admission Ticket', 'from €5.00* '],
#   ['Good Morning Barcelona', 'from €47.00* '],
#   ['Barcelona Insiders Segway Tour', 'from €39.00* '],
#   ['Gothic Quarter with Churros & Chocolate', 'from €50.00* '],
#   ['Hiking Costa Brava', 'from €150.00* '],
#   ['Exclusive SAILING EXPERIENCE in Barcelona', 'from €150.00* '],
#   ['Lesbian Night Tour: Barcelona Best Nightlife', 'from €79.00* '],
#   ['Feel like Gaudí: Tour & Workshop', 'from €53.00* '],
#   ['Escape the City on a Sailing Boat', 'from €65.00* '],
#   ['Private Barcelona Sightseeing Tour with Taxi, Van or Bus',
#    'from €199.00* '],
#   ['Gaudi & Tapas Private Tour', 'from €23.00* '],
#   ['Sagrada Família eScooter Tour', 'from €39.00* '],
#   ['eScooter Mini Tour', 'from €19.00* '],
#   ['Barcelona City tours', 'from €10.00* '],
#   ['Exclusive Romantic Sailing', 'from €490.00* '],
#   ['Skiline Jetski tour', 'from €150.00* '],
#   ['Barcelona Grand Segway Tour', 'from €49.00* '],
#   ['Romanic Girona Walking Tour', 'from €45.00* '],
#   ['Gothic Quarter & Picasso Museum Private tour', 'from €295.00* '],
#   ['Private Rollerblade Tour Around Barcelona', 'from €21.00* '],
#   ['Segway Tour & Sailing Experience Barcelona From Port Vell',
#    'from €99.00* '],
#   ['Born Tour', 'from €94.00* '],
#   ['Barceloneta Tour', 'from €50.00* ']],
#  [['Barcelona e-bike Tour: Gaudí and the Catalan Modernism', 'from €45.00* '],
#   ['Guided Bike Tour with Tapas in Barcelona', 'from €35.00* '],
#   ['Guided Bike Tour with Jamon Experience in Barcelona', 'from €45.00* '],
#   ['Private Vintage Bike and Photography Tour in Barcelona', 'from €59.00* '],
#   ['Private Full Day Tour of Tangier with private driver and official...',
#    'from €70.00* '],
#   ['Private Full Day Tour of Tangier & Asilah with private driver and...',
#    'from €100.00* '],
#   ['Segway Tour by The Sea in Barcelona', 'from €29.00* '],
#   ['Private 12-Hour Tour of Tangier & Asilah from Malaga or Marbella',
#    'from €205.00* '],
#   ['Small Group Tour of Colosseum With Dungeons', 'from €90.00* '],
#   ['Winery Tour with Private Luxury Vehicle from Barcelona', 'from €59.00* '],
#   ['Gaudì for kids small group tour', 'from €80.00* '],
#   ['Sagrada Familia eBike Full Day Tour with Cable Car and Boat Cruise...',
#    'from €99.50* '],
#   ['Private Shore Excursion or City Tour of Vigo', 'from €59.00* '],
#   ['Private 4-hour Walking Tour of Budapest', 'from €30.00* '],
#   ['Private Gay Night Tour in Barcelona', 'from €79.00* '],
#   ['E-Bike Private Gay Tour: Explore Barcelona', 'from €95.00* '],
#   ['Private 8 hour shore excursion to Taormina and Castelmola from Messina',
#    'from €105.00* '],
#   ['Canyoning in Vall de Núria Departure from Barcelona', 'from €175.00* '],
#   ['Gay Friendly Old Town Walking Tour in Barcelona', 'from €69.00* '],
#   ['Barcelona’s Modernist Houses Private Gay Tour with Casa Batlló',
#    'from €109.00* '],
#   ['Panoramic Montjuic Mountain Private Gay Walking Tour with Castle...',
#    'from €105.00* '],
#   ['Sitges Experience: Private Gay Walking Tour', 'from €85.00* '],
#   ['Montserrat Mountain Private Gay Tour with Lunch', 'from €195.00* '],
#   ['Private Sagrada Familia Gay Tour: Skip the Line Ticket', 'from €68.00* '],
#   ['Private Tour of Florence and Uffizi Gallery', 'from €98.00* '],
#   ['Day Trip To Amalfi Coast From Your Hotel in Naples or Sorrento',
#    'from €99.00* '],
#   ['Venice Private Tour of the Historical Monuments', 'from €85.00* '],
#   ['Family Tour of Pitti Palace and Boboli Gardens', 'from €108.00* '],
#   ['Pompeii Tour For Families With Pick Up in Naples or Sorrento',
#    'from €107.00* '],
#   ['Restaurant & Top nightclub package', 'from €59.00* ']],
#  [['San Sebastian Private Walking Tour', 'from €31.00* '],
#   ['Tarragona and Sitges Mediterranean Village Private Tour from Barcelona',
#    'from €140.00* '],
#   ['BEST SUNSET IN BARCELONA', 'from €58.00* '],
#   ['Barcelona Guided Tour in a Convertible', 'from €230.00* '],
#   ['Montserrat Hiking Experience from Barcelona', 'from €70.00* '],
#   ['Historical Montserrat Half-Day Hiking Tour from Barcelona',
#    'from €65.00* '],
#   ['Barcelona Private Airport Transfers', 'from €60.00* '],
#   ['Barcelona Costa Brava Hidden Bays Hike and Villages Small-Group Tour',
#    'from €79.00* '],
#   ['Private 2 Hour Walking Tour of Accademia Gallery in Venice with...',
#    'from €49.00* '],
#   ['Early Access Casa Batllo', 'from €37.00* '],
#   ['Barcelona Markets Tour with a Chef and Food Tasting - Premium Small...',
#    'from €36.00* '],
#   ['Breakfast Winery Experience - Wine Tasting Tour', 'from €90.00* '],
#   ['Jet Ski Experience without license in Barcelona', 'from €55.00* '],
#   ['Pyrenees Jeep Safari Day Tour from Barcelona', 'from €149.00* '],
#   ['Highlights and Hidden Gems Private Tour Barcelona', 'from €12.00* '],
#   ['Horseback Riding Tour in a Natural Park and Wine tasting in Penedés',
#    'from €168.00* '],
#   ['Private Barcelona Night Tour', 'from €21.00* '],
#   ['Barcelona Art and Architecture: Half-Day Guided Walking Tour',
#    'from €25.00* '],
#   ['Montjuic Panoramic Segway Tour', 'from €69.00* '],
#   ['Barcelona Airport Shuttle Transfer: Arrivals', 'from €20.00* '],
#   ['Park Guell Private Tour', 'from €67.00* '],
#   ['Take Photos Like a PRO with a Local', 'from €37.00* '],
#   ['Sailing Boat: Sunset Cruise', 'from €58.00* '],
#   ['Montserrat Guided Hiking Experience from Barcelona', 'from €95.00* '],
#   ['Small Group Modernism and Gaudi Walking Tour in Barcelona',
#    'from €39.00* '],
#   ['Magic Tasting Sagrada Familia Skip The Line Wine And Tapas',
#    'from €52.50* '],
#   ['Via Ferrata Teresina in Montserrat Barcelona', 'from €220.00* '],
#   ['barcelona electric bike and goleta tour', 'from €50.00* '],
#   ['Private Guided Walking Tour of Gothic Quarter in Barcelona',
#    'from €35.00* '],
#   ["Barcelona's best private family food tour", 'from €51.00* ']],
#  [['Barcelona Modernism Art Museum Tickets with Optional Guided Tour',
#    'from €10.00* '],
#   ['Guided Tour of Sagrada Familia and Sant Pau Art Nouveau', 'from €59.00* '],
#   ["Private Tour 'a la Carte' in Barcelona", 'from €93.00* '],
#   ['Catalan Gastronomy: Small-Group Guided Walking Tour in Barcelona',
#    'from €59.00* '],
#   ['Barcelona Shore Excursion: Post-Cruise Half-day Private Highlights...',
#    'from €59.00* '],
#   ['Private 4-Hour Tour of Vatican Museum, Sistine Chapel and Rome...',
#    'from €138.00* '],
#   ['Private Cooking Class and Guided Tour of La Boqueria Market',
#    'from €450.00* '],
#   ['Private 4-Hour Tour of Rome with private driver and official tour...',
#    'from €88.00* '],
#   ['Transfer Airport Barcelona to Salou Cambrils Costa Daurada',
#    'from €450.00* '],
#   ['Private Guided Walking Tour in Granada', 'from €50.00* '],
#   ['Multi-cultural and Olympic Barcelona', 'from €21.00* '],
#   ['Private Half-Day Walking Tour of Alicante', 'from €28.00* '],
#   ['Exclusive Cava & Chocolate Experience', 'from €65.00* '],
#   ['Valencia Private City Tour', 'from €54.00* '],
#   ['Alicante Private Half Day Tour with Hotel Pick-up', 'from €69.00* '],
#   ['Kayak Rental', 'from €25.00* '],
#   ['Parasailing Adventure in Barcelona', 'from €95.00* '],
#   ['Gladiator Experience: Ancient Rome with Special Access From the Arena...',
#    'from €79.00* '],
#   ['Yacht Excursion in Barcelona', 'from €450.00* '],
#   ['Small Group Tour of Baroque Rome', 'from €50.00* '],
#   ['Private Tour Montseny Hiking from Barcelona', 'from €180.00* '],
#   ['Full Moon on a Catamaran', 'from €65.00* '],
#   ['Private Walking Tour of Valencia', 'from €26.00* '],
#   ['Madrid Top10 eBike Tour', 'from €27.00* '],
#   ['Skip The Line With Arena Entrance: Ancient Rome Private Tour',
#    'from €79.00* '],
#   ['Private 6-hour Tour of Italica and Seville', 'from €89.00* '],
#   ['Private Full Day Tour of Carmona and Seville from Seville',
#    'from €115.00* '],
#   ['Hola Barcelona! Your Private Fun Family Introduction', 'from €19.00* '],
#   ['Paella Cooking Small Group Workshop with a Chef with Lunch',
#    'from €78.00* '],
#   ['Ferrari Driving in Barcelona', 'from €59.00* ']],
#  [['Las Golondrinas Sightseeing Cruise of Barcelona Port', 'from €7.70* '],
#   ['Barcelona Pub Crawl', 'from €13.00* '],
#   ['Tarragona and Sitges Tour from Barcelona', 'from €89.00* '],
#   ['Montserrat Hot-Air Balloon Experience & Monastery Visit - Premium...',
#    'from €185.00* '],
#   ['Dali Museum, Figueres and Cadaqués Small Group Tour with Hotel Pick...',
#    'from €120.00* '],
#   ['PortAventura Park Day Trip from Barcelona', 'from €58.65* '],
#   ['Savor Spain', 'from €99.00* '],
#   ['Barcelona Segway Tour', 'from €55.00* '],
#   ['Girona Game of Thrones City', 'from €55.00* '],
#   ['Tapas and Traditions of Barcelona Day Food Tour', 'from €79.00* '],
#   ['Gaudi Bike Tour with Skip-the-Line Sagrada Familia Ticket',
#    'from €58.50* '],
#   ['3-hour Barcelona Evening Tapas Tour', 'from €20.00* '],
#   ['Stories and Legends of the Gothic Quarter Walking Tour', 'from €15.00* '],
#   ['Barcelona Gothic Quarter Family and Kids’ Small-Group Walking Tour',
#    'from €15.00* '],
#   ['The Complete Gaudi Tour: Casa Batlló, La Pedrera, Park Guell...',
#    'from €135.00* '],
#   ['Hot-Air Balloon Flight Over Catalonia with Pick-up from Barcelona',
#    'from €170.00* '],
#   ['Priorat Wineries Tour from Barcelona, Including Wine Tastings and...',
#    'from €190.00* '],
#   ['Barcelona Coast Helicopter Tour', 'from €69.00* '],
#   ['2.5-hour Small-Group Sunset Cruise from Barcelona', 'from €80.00* '],
#   ['Barcelona Shore Excursion with Montserrat Tour and Skip-the-Line Park...',
#    'from €106.00* '],
#   ['Private Walking Skip the Line Sagrada Familia Tour with Independent...',
#    'from €68.00* '],
#   ['Barcelona Tapas Walking Tour', 'from €85.00* '],
#   ['Vegan Food Tour Experience in Barcelona', 'from €74.00* '],
#   ['Jewish Quarter of Barcelona: one of the most important Jewish...',
#    'from €45.00* '],
#   ['Photography Walk Through Barcelona', 'from €45.00* '],
#   ['Barcelona Gaudí Segway Tour', 'from €59.00* '],
#   ['The Classic Segway Tour Barcelona', 'from €49.00* '],
#   ["Barcelona's Coastline Helicopter Flight with Optional Pick-up and...",
#    'from €79.00* '],
#   ['Montjuïc Electric BikeTour', 'from €38.00* '],
#   ['Tapas and Flamenco Evening', 'from €35.00* ']],
#  [['Smart-glasses gothic tour through the ancient Barcelona', 'from €19.00* '],
#   ['Madrid Art eBike Tour', 'from €39.00* '],
#   ['CRAZY SOFA ADVENTURE', 'from €30.00* '],
#   ['Barcelona Gothic to Modernism Bike Tour', 'from €24.00* '],
#   ["Casa Vicens Guided Tour (Gaudi's First House)", 'from €22.00* '],
#   ['Private Artsy Side of Barcelona', 'from €8.00* '],
#   ['Barcelona Casa Amatller Tour with Skip-the-Line Access', 'from €24.00* '],
#   ['Room Of Riddles: The Art Collector Escape Room in Barcelona',
#    'from €20.00* '],
#   ['Banana Boat', 'from €20.00* '],
#   ['Barcelona Shore Excursion: Barcelona Card with Guidebook',
#    'from €20.00* '],
#   ['2,5-hour Barcelona City Bike Tour', 'from €18.00* '],
#   ['Barcelona Art Tour', 'from €35.00* '],
#   ['Jet Ski Barcelona Skyline Tour Experience', 'from €59.00* '],
#   ['Small Group Photo Experience in Barcelona', 'from €50.00* '],
#   ['Bitemojo self-guided tours of Barcelona: Gothic Food Tour',
#    'from €31.20* '],
#   ['Guided Tour at Requesens Palace', 'from €8.00* '],
#   ['The Passion of Sailing with Vermouth', 'from €55.00* '],
#   ['Hiking on the top of Barcelona Tibidabo', 'from €44.00* '],
#   ['Kayak and Paddleboard Experience in Barcelona', 'from €30.00* '],
#   ['Windsurfing Lesson in Barcelona', 'from €49.00* '],
#   ['3.5 Hour Private City Tour of Granada', 'from €43.00* '],
#   ['Half-Day Private City Tour of Málaga', 'from €99.00* '],
#   ['Private City Tour of Marbella and Puerto Banús with Hotel Pick-up',
#    'from €61.00* '],
#   ['Half-Day Private Shore Excursion of Cadiz', 'from €80.00* '],
#   ['Full-Day Private Shore Excursion to Seville from Cadiz', 'from €115.00* '],
#   ['Terroir & Grapes Priorat wineries tour - Private tour', 'from €485.00* '],
#   ['Vatican Museums, Pinacoteca, Sistine Chapel Small Group Tour',
#    'from €50.00* '],
#   ['Private Tour: Half-Day City Tour by Taxi', 'from €55.00* '],
#   ['Private 4 hour tour of Cannes and Antibes from Cannes',
#    'from €1,335.00* '],
#   ['Wine and Tapas Tasting Tour', 'from €90.00* ']],
#  [['Barcelona Card with Guidebook', 'from €45.00* '],
#   ['Barcelona Guided Tour by Segway', 'from €45.00* '],
#   ['Spanish Guitar Concert at the Basilica of Santa Maria del Pi in...',
#    'from €23.00* '],
#   ['Opera and Flamenco Performance in Barcelona at Teatre Poliorama or...',
#    'from €35.00* '],
#   ["Picasso's Barcelona on Electric Bike", 'from €30.60* '],
#   ['Barcelona UnCensored Tour', 'from €15.00* '],
#   ['Barcelona Private Food Tour:10 Tastings', 'from €50.00* '],
#   ['Barcelona at Night: Local Tapas & Drinks Private Tour', 'from €31.00* '],
#   ['Barcelona Sightseeing Bike Tour', 'from €25.00* '],
#   ['Private Day-trip to Costa Brava from Barcelona', 'from €78.00* '],
#   ['Sunny Barcelona Photoshoot', 'from €49.00* '],
#   ['Flamenco Show and Drink', 'from €35.00* '],
#   ['Barcelona Bites & Flavors: Private Food Tour', 'from €28.00* '],
#   ['Room Of Riddles: The Harbour Master', 'from €20.00* '],
#   ['La Boqueria Market and Cooking Class in Barcelona', 'from €85.00* '],
#   ['2 Hour Hidden Oasis Retiro Park Madrid Small Group Segway Tour',
#    'from €35.00* '],
#   ['Barcelona Bike Tour', 'from €22.00* '],
#   ['Erotic Museum of Barcelona Admission Ticket with Glass of Champagne',
#    'from €10.00* '],
#   ['The Real Side of Andorra: Private Day Trip', 'from €90.00* '],
#   ['Gaudí eScooter Tour', 'from €46.00* '],
#   ['Flamenco Show and Dinner', 'from €50.00* '],
#   ['Sagrada Familia Segway Tour', 'from €64.00* '],
#   ['Montjuic eScooter tour', 'from €39.00* '],
#   ['Barcelona Intro Segway Tour', 'from €29.00* '],
#   ['Private Barcelona Shore Excursion by Minivan', 'from €41.00* '],
#   ['Private Sailing Boat Trip', 'from €299.00* '],
#   ['Collserola Hiking Tour', 'from €72.00* '],
#   ['Escape Room & Sailing Experience Barcelona from Port Vell',
#    'from €59.00* '],
#   ['Barcelona Modernist Houses: Gaudi Private Gay Walking Tour',
#    'from €65.00* '],
#   ['GPS Guided Gaudí eScooter Tour & La Pedrera Ticket', 'from €60.00* ']],
#  [['Private Wine Tour to Costa Brava & Dali - Full day from Barcelona or...',
#    'from €205.00* '],
#   ['Barcelona Sunset Sailing Experience', 'from €39.00* '],
#   ['Via Ferrata de les Dames', 'from €200.00* '],
#   ['Rock Climbing Discovery', 'from €200.00* '],
#   ['Private Small Group Full Day Tour- Montserrat and Cava Visit with...',
#    'from €160.00* '],
#   ['Barcelona Private Guided Tour by Minibus', 'from €125.00* '],
#   ['Tibidabo Panoramic Guided Walking Tour in Barcelona', 'from €65.00* '],
#   ['Heart of Catalonia: Guided Hiking Experience in Barcelona',
#    'from €150.00* '],
#   ['BARCELONA STREET ART TOUR', 'from €32.00* '],
#   ['Exclusive and Private Day Charter Barcelona 3h', 'from €85.50* '],
#   ['Costa Brava Small Group Hiking Tour from Barcelona', 'from €109.00* '],
#   ['Full Day Guided Tour: Three Medieval Towns Plus Lunch', 'from €160.00* '],
#   ['Small-Group Barcelona Night Tour By Vespa Scooter', 'from €170.00* '],
#   ['12-Hour Private tour of Andorra from Barcelona', 'from €122.00* '],
#   ['Private Arrival Transfer from Barcelona Airport to Sitges City',
#    'from €21.33* '],
#   ['Barcelona Private Tour to Tibidabo Mountain and Labyrinth Park',
#    'from €179.00* '],
#   ['Private Full Day tour of Porto from Lisbon', 'from €99.00* '],
#   ['Private tour of Sintra from Lisbon with driver and separate guide',
#    'from €65.00* '],
#   ['Private full day city tour of Lisbon with driver and separate guide...',
#    'from €102.00* '],
#   ['Private full day city tour of Lisbon with driver and separate guide',
#    'from €80.00* '],
#   ['Private 4 hour tour of Porto with driver and separate guide',
#    'from €63.00* '],
#   ['Private Half-Day City Tour of Lisbon with Driver and Separate Guide',
#    'from €66.00* '],
#   ['Private Departure Transfer from Sitges City to Barcelona Airport',
#    'from €21.33* '],
#   ['Private 6 hour tour of Fatima from Porto', 'from €1,190.00* '],
#   ['Private Tour of Santiago de Compostela from Porto', 'from €84.00* '],
#   ['Private walking tour of Porto', 'from €32.00* '],
#   ['Barcelona in One Day Private Tour', 'from €78.40* '],
#   ['Private Barcelona Airport - Sitges Round-Trip Transfer', 'from €42.30* '],
#   ['SAGRADA FAMILIA EXPRESS TOUR', 'from €73.10* '],
#   ['Wandermoda Boutique Shopping Experience', 'from €55.00* ']],
#  [['Sagrada Familia Official Private Tour', 'from €85.00* '],
#   ['Tapas Evening Walking Tour in Barcelona', 'from €59.00* '],
#   ['Welcome to Barcelona with Sagrada Familia', 'from €45.00* '],
#   ['Private Day Trip from Barcelona: Wine Tasting in the Vineyards',
#    'from €136.00* '],
#   ['Barcelona Food and Wine Tour at Midday', 'from €75.00* '],
#   ['Private Barcelona Tapas Tour and Flamenco Show', 'from €70.00* '],
#   ['Costa Brava Small Group with Hotel Pick-Up and Panoramic Boat Ride',
#    'from €95.00* '],
#   ['Paella Hands-On Cooking Experience in Barcelona', 'from €114.00* '],
#   ['Sailing Wine and Tapas - Premium small group', 'from €150.00* '],
#   ['Boutique Wineries Wine and Tapas Small Group Tour', 'from €187.00* '],
#   ['Sailing Experience in Barcelona', 'from €75.00* '],
#   ['Private Walking Tour of Segovia', 'from €22.00* '],
#   ['Private Girona and Figueres Tour from Barcelona', 'from €140.00* '],
#   ['Barcelona Hot-Air Balloon Ride', 'from €160.00* '],
#   ['Gothic Quarter and Sagrada Familia Private Guided Tour in Barcelona',
#    'from €80.00* '],
#   ['Art and Tapas Walking Tour in Barcelona', 'from €89.00* '],
#   ['Barcelona Old Town Private Walking Tour', 'from €69.00* '],
#   ['Hot Air Balloon flight Barcelona', 'from €160.00* '],
#   ['Montserrat Afternoon Tour with Privileged Access to Hidden Areas of...',
#    'from €68.40* '],
#   ['Barcelona: Private Gaudi Tour and Sagrada Familia Ticket',
#    'from €112.00* '],
#   ['Barcelona Transfer: Cruise Port to Barcelona Airport', 'from €73.75* '],
#   ['Sea Adventure: Parasailing, kayak or Paddle Surf in Barcelona',
#    'from €75.00* '],
#   ['Classic yacht tour in Barcelona, swimming and appetizer in Bon Temps...',
#    'from €120.00* '],
#   ['Barcelona Highlights: Private Guided Tour', 'from €300.00* '],
#   ['Early Small Combination Tour of the Vatican and the Colosseum',
#    'from €110.00* '],
#   ['Barcelona Fishing Experience', 'from €550.00* '],
#   ['Full Day Guided Tour: Montserrat & Organic Winery Plus Lunch',
#    'from €160.00* '],
#   ['Segway Flexible Private Tour in Barcelona', 'from €49.00* '],
#   ['Private Guided Gastronomy Tour: Selection of Tapas in Barcelona',
#    'from €120.00* '],
#   ['Dali Figueres and Púbol Full-Day Tour with Small Group and Hotel Pick...',
#    'from €120.00* ']],
#  [['Food Tour as a Local in Barcelona', 'from €63.00* '],
#   ['Private Tour: Costa Brava Hike from Barcelona', 'from €180.00* '],
#   ["La Boqueria Market Tour and Healthy Cooking Class in a Local's Home...",
#    'from €89.10* '],
#   ['Barcelona Tapas walking Tour with Flamenco Show', 'from €103.00* '],
#   ['Learn to Cook Organic, Healthy, Thoughtfully Sourced Spanish Cuisine...',
#    'from €73.10* '],
#   ['Full-Day Private Wine Tour and Montserrat Mountain Experience',
#    'from €158.00* '],
#   ['Private Custom Tour of A Coruña with Guide and Pick-up', 'from €64.00* '],
#   ['Sunset with cocktails or cava', 'from €70.00* '],
#   ['Private Official Guide to Visit Alhambra in Granada from Seville',
#    'from €110.00* '],
#   ['Exclusive and Private Day Charter Barcelona 2h', 'from €60.00* '],
#   ['Barcelona Charms and Secrets e-bike tour', 'from €36.00* '],
#   ['Private Costa Brava and Empuries Tour with Hotel Pick-Up and...',
#    'from €140.00* '],
#   ['BARCELONA AND MONTSERRAT FULL DAY TOUR', 'from €480.00* '],
#   ['Private Tour of Santiago de Compostela from A Coruña', 'from €66.00* '],
#   ['Barcelona Highlights: Private Guided Family Tour', 'from €135.00* '],
#   ['Barcelona Modernist Houses and Gaudi Private Walking Tour',
#    'from €65.00* '],
#   ['Day Trip of Figueras and Girona', 'from €267.00* '],
#   ['Barcelona Highlights and Camp Nou Private Tour', 'from €160.00* '],
#   ['Montjuic bike tour', 'from €49.00* '],
#   ['8-Hour Private tour of Dali Museum in Figueras and Cadaques from...',
#    'from €220.00* '],
#   ['Gothic bike tour', 'from €49.00* '],
#   ['6-Hour Private tour of Dali Museum in Figueras from Barcelona',
#    'from €170.00* '],
#   ['Sagrada Familia bike tour', 'from €49.00* '],
#   ['Private Full Day Gaudi Tour: Pedrera Casa Batllo Sagrada Familia and...',
#    'from €250.00* '],
#   ['Beach bike tour', 'from €39.00* '],
#   ['Walking tour Barcelona', 'from €39.00* '],
#   ['Contemporary art bike tour', 'from €59.00* '],
#   ['Private 3-Hour Tapas Tour of Granada', 'from €75.00* '],
#   ['Miami Highlights Private Tour with Shared Boat Ride', 'from €109.00* '],
#   ['Private Tour: Montserrat and Cava Visit', 'from €120.00* ']],
#  [['Pyrenees Mountains Small Group Day Trip from Barcelona', 'from €99.00* '],
#   ['Madrid Highlights Guided Segway Tour', 'from €49.00* '],
#   ['Barcelona Magic Fountain and Night Lights Premium Small Group Tour by...',
#    'from €40.00* '],
#   ['Ice Barcelona Admission Ticket', 'from €16.00* '],
#   ['National Art Museum of Catalonia Entrance Ticket', 'from €12.00* '],
#   ['Barcelona Super Saver Montjuic Cable Car and Montserrat Sightseeing...',
#    'from €101.00* '],
#   ['Wine and Cheese Tasting in Barcelona', 'from €25.00* '],
#   ['Barcelona Electric Bike Tour with Skip-the-Line Sagrada Familia',
#    'from €69.00* '],
#   ['Sailing Experience from Port Vell in Barcelona with Optional Brunch',
#    'from €39.00* '],
#   ['Wine Tasting Experience in Barcelona', 'from €18.00* '],
#   ['Montserrat Royal Basilica Half-Day Trip from Barcelona', 'from €44.00* '],
#   ['Small-Group Barcelona Tapas Tour with a Local', 'from €63.00* '],
#   ['Joan Miro Foundation Barcelona Skip the Line Admission Ticket',
#    'from €12.00* '],
#   ['FLAMENCO SHOW in LAS RAMBLAS', 'from €15.00* '],
#   ['Barcelona Catamaran Party Sail', 'from €46.00* '],
#   ['Fast Track Access to Park Guell', 'from €24.90* '],
#   ['Half-Day Montserrat Tour with Small Group and Hotel Pickup',
#    'from €78.00* '],
#   ['Barcelona Day Trip: Montserrat, Colonia Guell, and Gaudi Crypt',
#    'from €71.00* '],
#   ['Barcelona Private Tour with Skip-the-Line Access to La Sagrada Familia',
#    'from €120.00* '],
#   ['Barcelona Evening Flamenco Show and Gourmet Dinner with Premium Small...',
#    'from €75.00* '],
#   ['Skip the Line La Sagrada Família Express Tour', 'from €39.00* '],
#   ['Barcelona Ghost Night Walking Tour', 'from €14.00* '],
#   ["Casa Vicens ( Gaudi's first house) Direct Entry", 'from €12.00* '],
#   ['Cocktail Masterclass with Tapas', 'from €35.00* '],
#   ['Mediterranean Cooking Class in Barcelona', 'from €75.00* '],
#   ['2 hour Sailing Cruise Barcelona', 'from €49.00* '],
#   ['Tapas and Flamenco Show at Tablao Flamenco Cordobes', 'from €59.00* '],
#   ['Columbus Monument Ticket with Upgrade Wine Tasting in Barcelona',
#    'from €6.00* '],
#   ['Discover Gaudi & Modernisme', 'from €15.00* '],
#   ['Sidecar Barcelona Highlights Tour', 'from €100.00* ']],
#  [['Private Tour: Markets and Tapas from Barcelona', 'from €98.00* '],
#   ['Historical E-bike Tour in Barcelona', 'from €34.00* '],
#   ['Guided Tour Santiago de Compostela Cathedral and Museum', 'from €28.00* '],
#   ['Barcelona’s Modernist Houses Private Tour With Casa Batlló Ticket',
#    'from €109.00* '],
#   ['Private Family Day Trip: Magical Montserrat', 'from €79.00* '],
#   ['Fishing Kayak Excursion', 'from €95.00* '],
#   ['Barcelona Private Transfer from El Prat Airport to Cruise Terminal',
#    'from €13.34* '],
#   ['Barcelona Gaudí Sightseeing Tour from Costa Brava', 'from €30.00* '],
#   ['Mosaic class for families in Barcelona for 4 persons', 'from €169.00* '],
#   ['Sagrada Família Tour with Flamenco Show', 'from €77.00* '],
#   ['Sunset Sailing Small Group Experience with Live Spanish Guitar from...',
#    'from €81.00* '],
#   ['Barcelona Coastal Boat Rental', 'from €90.00* '],
#   ['Artistic Barcelona with Casa Batllo and Park Güell', 'from €78.00* '],
#   ['5-Hour Guided Tour in Barcelona', 'from €49.00* '],
#   ['Pyrenees Ski Day Trip from Barcelona', 'from €87.00* '],
#   ['Winery and Wine Tasting Tour in el Penedes from Barcelona',
#    'from €68.00* '],
#   ['Barcelona Camp Nou Football Stadium Tour from Costa Brava with...',
#    'from €55.00* '],
#   ['Barcelona City Arquitecture Tour by Vespa Scooter', 'from €80.00* '],
#   ['Modernism and Gaudí Walking Tour in Barcelona', 'from €16.00* '],
#   ['Sea Front Explorer: Segway and Jet Ski in Barcelona', 'from €65.00* '],
#   ['Wine Tasting Tour in Barcelona', 'from €63.00* '],
#   ['Madrid Up&Down eBike Tour', 'from €34.00* '],
#   ['Skip the Line: Casa Batllo and Gaudi Guided Walking Tour in Barcelona',
#    'from €59.00* '],
#   ['Madrid Airport to City Center: 1-Way Premium Private Transfer',
#    'from €68.00* '],
#   ['Full-Day Montserrat Monastery and Sacristy Tour from Barcelona with...',
#    'from €79.00* '],
#   ['Wine & Oil Tasting Tour near Barcelona', 'from €95.00* '],
#   ['Sagrada Familia Private Segway Tour', 'from €79.00* '],
#   ['Visit And Tasting In Traditional Craft Brewery In Barcelona',
#    'from €39.00* '],
#   ['Small-Group Markets Tour, Paella Cooking Workshop, and Lunch with a...',
#    'from €36.00* '],
#   ['2-hour Barcelona Segway Tour', 'from €55.00* ']],
#  [['Private 2 or 3 Hour Walking Tour of Venice with private official tour...',
#    'from €32.00* '],
#   ['Barcelona Gems - Private City Bike Tour', 'from €65.00* '],
#   ['Barcelona Magic Lights Private Bike Tour', 'from €45.00* '],
#   ['Private Balloon Ride', 'from €165.00* '],
#   ['Private tour or shore excursion to Santiago de Compostela from Vigo',
#    'from €82.00* '],
#   ['Engaging Tour For Kids: Discovering Medieval Florence', 'from €113.00* '],
#   ['Private 6-Hour tour to Pompeii and Herculaneum from Naples',
#    'from €140.00* '],
#   ['Private 4-Hour Walking Tour of Naples with official tour guide',
#    'from €40.00* '],
#   ['Hot Air Balloon Barcelona', 'from €228.00* '],
#   ['Private 4 hour walking tour of Valleta with official tour guide',
#    'from €30.00* '],
#   ['Private Tour of Pompeii Archaeological site with official tour guide',
#    'from €45.00* '],
#   ["Barcelona '92 Segway Tour", 'from €39.00* '],
#   ['Limousine & nightclub Barcelona', 'from €345.00* '],
#   ['The Magic of Gràcia - Private Evening Tour', 'from €8.00* '],
#   ['Trail Running Barcelona', 'from €85.00* '],
#   ['Private Hot Air Balloon over Volcanoes from Barcelona', 'from €340.00* '],
#   ['4-Hour Gaudi Mosaic Workshop in Barcelona', 'from €85.00* '],
#   ['Private Vineyards & Barcelona Beaches by eBike', 'from €90.00* '],
#   ['Private Costa Brava Full Day Tour from Barcelona', 'from €190.00* '],
#   ['Montserrat Monastery Tour & Hot Air Balloon Flight, Including...',
#    'from €340.00* '],
#   ['Private Girona & Dalí Full Day Tour from Barcelona', 'from €190.00* '],
#   ['Private Guided Half Day City Tour in Madrid with Public Transportation',
#    'from €42.00* '],
#   ['Costa Brava Villages Electric Bike Self-Guided GPS Tour with Wine',
#    'from €65.00* '],
#   ['Private 4-Hour City Tour of Milan with private driver and official...',
#    'from €65.00* '],
#   ['Private 4-Hour Walking City Tour of Milan with private official tour...',
#    'from €45.00* '],
#   ['Private Tour: San Siro Stadium and Modern Milan Sightseeing',
#    'from €116.00* '],
#   ['Self-Guided 5-Day Family Tour in the Pyrenees', 'from €717.00* '],
#   ['Prado Museum Tour with Private Guide and Transport in Madrid',
#    'from €99.00* '],
#   ['Vatican For Kids Tour with Egyptian Museum', 'from €90.00* '],
#   ['Explore the Vatican with Kid Friendly Guide', 'from €98.00* ']],
#  [['Barcelona Segway Panoramic Tour', 'from €29.00* '],
# ...
#   ['Sagrada Familia and Park Guell on a Luxury Open Top Minibus Small...',
#    'from €89.00* '],
#   ['Private Half-Day Tour in Natural Park with Horseback Riding in...',
#    'from €110.00* '],
#   ['Semi Private: skip the line Sagrada Familia tour', 'from €49.00* '],
#   ['Barcelona Skyline: Yacht Tour with Professional Skipper', 'from €65.00* '],
#   ['Barcelona Semi Private Tour', 'from €120.00* ']],
#  [['Jet Ski Experience in Barcelona', 'from €65.00* '],
#   ['Private Barcelona Like a Local Tour', 'from €14.00* '],
#   ['Gaudi Experience Admission Ticket', 'from €9.00* '],
#   ['Barcelona Self- Guided Audio Tour', 'from €17.81* '],
#   ['Barcelona Egyptian Museum Admission Ticket', 'from €11.00* '],
#   ['MEAM, European Museum of Modern Art Admission Ticket', 'from €9.00* '],
#   ["Museu d'Historia de Catalunya Admission Ticket", 'from €6.50* '],
#   ['Full Day Guided Tour and Skip the Line: Sagrada Familia, Park Güell...',
#    'from €160.00* '],
#   ['Barcelona Super Saver: Montserrat Day Trip and Barcelona Gaudi Tour',
#    'from €98.00* '],
#   ['Girona and Costa Brava Private Day Trip from Barcelona', 'from €110.00* '],
#   ['Private Barcelona and Sagrada Familia Half Day Tour with Hotel Pick-up',
#    'from €120.00* '],
#   ['Shore Excursion: Barcelona City Tour Hop-On Hop-Off', 'from €30.00* '],
#   ['Helicopter Flight and Sailing Experience Small Group from Port Vell',
#    'from €139.00* '],
#   ['Cava and Wine Tour from Barcelona', 'from €125.00* '],
#   ['Private Departure Transfer from Central Barcelona to El Prat Airport',
#    'from €13.34* '],
#   ['Private Montjuic Mountain Tour with Visit to Olympic Park and Plaza...',
#    'from €105.00* '],
#   ['Early Picasso Museum & Gothic Quarter Tour with Breakfast at Palau de...',
#    'from €30.00* '],
#   ['Barcelona Half Day Guided Panoramic Bus and Walking Tour',
#    'from €58.00* '],
#   ['Hard Rock Cafe Barcelona', 'from €19.42* '],
#   ['Ferrari Driving and Water Activities in Barcelona', 'from €99.00* '],
#   ['Ebike Tour:Alta Alella Winery Visit and Wine Tasting Premium Small...',
#    'from €49.50* '],
#   ['Citizen Segway Tour Barcelona', 'from €69.00* '],
#   ['2-Hour Small Group Cruise from Barcelona', 'from €50.00* '],
#   ['Private Day-Trip to Tarragona', 'from €63.00* '],
#   ['Private WWII Side Car Tour with a Local in Barcelona', 'from €71.00* '],
#   ['GPS Scooter Rental in Barcelona', 'from €25.00* '],
#   ['Barcelona Kick-start Private Tour', 'from €5.00* '],
#   ["'The Shadow of the Wind' Walking Book Tour in Barcelona", 'from €14.00* '],
#   ['GoCar Discover Gaudi', 'from €45.00* '],
#   ['3.5-hour Barcelona, Montjuic Hill, and Gothic Quarter E-Bike Tour',
#    'from €39.00* ']],
#  [['Private 10-Hour Tour of Pompeii from Rome', 'from €176.00* '],
#   ['Private 3-Hour Walking Tour of Rome with private official tour guide',
#    'from €35.00* '],
#   ['Private 8 hour Shore excursion from Valleta Cruise Port', 'from €69.00* '],
#   ['Private 4-Hour Tour of Ostia Antica from Rome', 'from €80.00* '],
#   ['Traditional catalan appetizer on board', 'from €79.00* '],
#   ['Montseny Guided Hiking Tour from Barcelona with Organic-friendly Lunch',
#    'from €129.00* '],
#   ['Private Luxury Transfer from Fiumicino to Rome City Centre',
#    'from €22.00* '],
#   ['Private Luxury Transfer from Rome City Centre to Fiumicino Airport',
#    'from €22.00* '],
#   ['Barcelona highlights semi-private tour', 'from €120.00* '],
#   ['Shore tour of Rome and Vatican', 'from €280.00* '],
#   ['Roman Highlights Private Tour', 'from €55.00* '],
#   ['Walk with Bernini Caravaggio Michelangelo and Raphael', 'from €45.00* '],
#   ['Vatican Treasures Small Group Tour', 'from €58.50* '],
#   ["Florence's must-see sights", 'from €87.00* '],
#   ['Private Luxury Transfer from Palermo City Centre to Palermo Airport',
#    'from €20.00* '],
#   ['Traditional Christmas Meal Cooking Class in Barcelona', 'from €110.00* '],
#   ['Ancient Roman Times Small Group', 'from €45.00* '],
#   ['Homey Tour of Sagrada Familia and Park Guell', 'from €94.00* '],
#   ['Roman Highlights and Colosseum', 'from €163.00* '],
#   ['Ancient Times in Rome Private Tour', 'from €67.00* '],
#   ['Semi Private Tour of Barcleona', 'from €120.00* '],
#   ['A day with Gaudi and Picasso Private tour', 'from €170.00* '],
#   ['Explore the Gothic District and Sagrada Familia', 'from €83.00* '],
#   ['Barcelona Shore Excursion: Private Guided Tour with Skip the Line...',
#    'from €180.00* '],
#   ['Private Tour of Bilbao from San Sebastian', 'from €84.00* '],
#   ['Gaudi Tour and Local Art Workshop in Barcelona', 'from €72.00* '],
#   ['Nadal de la Boadella Estate Tour with Mediterranean Brunch',
#    'from €58.00* '],
#   ['Private Jewish Heritag and history - Girona and Besalu', 'from €269.00* '],
#   ['Full-Day Nuria Valley Hiking Tour from Barcelona', 'from €139.00* '],
#   ['Jewish Heritag and history Girona and Besalu', 'from €115.00* ']],
#  [['4-Hour Private Guided Walking Tour in Seville', 'from €67.00* '],
#   ['Dalí Museum Guided Tour', 'from €38.00* '],
#   ["Barcelona's Must-Do Private Family Tour", 'from €12.00* '],
#   ['Private 12-Hour Tour of Chefchaouen from Malaga or Marbella',
#    'from €243.00* '],
#   ['Sightseeing Sailboat Tour from Barcelona', 'from €65.00* '],
#   ['Paella and Tapas Small-Group Cooking Class in Barcelona', 'from €59.95* '],
#   ['Costa Brava Weekend Sail Cruise from Barcelona', 'from €480.00* '],
#   ['Barcelona on a Segway: Guided Tapas Tour', 'from €110.00* '],
#   ['Romantic Sunset Cruise in Barcelona', 'from €390.00* '],
#   ['Hoverboard Barcelona', 'from €75.00* '],
#   ['Private Spanish Wine Tasting Experience in Barcelona', 'from €71.00* '],
#   ['Private Barcelona City Tour and Penedés Cava Tasting', 'from €175.00* '],
#   ['Family Sailing Tour in Barcelona', 'from €250.00* '],
#   ['Private Day Tour to Vall de Núria and Camprodón from Barcelona',
#    'from €200.00* '],
#   ['Gaudi Experiencia, Colonia Guell and Torres Bellesguad Private Tour',
#    'from €225.74* '],
#   ['PRIVATE 4 HOUR TOUR OF CAMP NOU AND MOST EMBLEMATIC SITES OF BARCELONA',
#    'from €139.00* '],
#   ['Private Full-Day Tour to Sitges and Bodegas Torres', 'from €145.00* '],
#   ['Private Tour: Salvador Dali Museum at Figueres and Girona Day Trip...',
#    'from €272.50* '],
#   ['Costa Daurada Private Sailing Trip', 'from €390.00* '],
#   ['Barcelona Walking Tour, Tapas Dinner & Flamenco Show', 'from €110.00* '],
#   ['Private Round Trip to Montserrat from Barcelona Center', 'from €24.90* '],
#   ['Private Walking Tour, Tapas Dinner & Flamenco Show', 'from €150.00* '],
#   ['Private 8 hour tour to Agrigento (Valley of the Temples) from Palermo',
#    'from €65.00* '],
#   ['Private Electric Bike Guided Tour in Barcelona', 'from €38.00* '],
#   ['The Great Gaudi FAMILY Tour of Barcelona', 'from €85.00* '],
#   ['Private Customizable Tour of Sevilla', 'from €95.00* '],
#   ['FAMILY Gothic Quarter Tour in Barcelona', 'from €55.00* '],
#   ['The Gothic Quarter & E-Bike Tour of Barcelona', 'from €55.00* '],
#   ['Private Wine tasting Tour with tapas in Barcelona', 'from €44.00* '],
#   ['Tapas Cooking Experience in Barcelona', 'from €90.00* ']],
#  [["Gaudi's Masterpieces Private Tour in Barcelona", 'from €138.10* '],
#   ['Private Montserrat and Penedes Day Tour form Barcelona', 'from €140.00* '],
#   ['Private 10-Hour Tour of Sevilla from Malaga or Marbella',
#    'from €129.00* '],
#   ['Bilbao Private City Tour with Hotel Pick-up', 'from €89.00* '],
#   ['Early Entrance Montserrat & Gourmet Cava Tour with Lunch at...',
#    'from €150.00* '],
#   ['Private Guided Tour: Picasso in Barcelona', 'from €68.00* '],
#   ['Private Tour: Girona, Pals and Peratallada Medieval Towns from...',
#    'from €117.00* '],
#   ['Private Wine Tour Cooking & Sunset tasting in Penedes - Half Day from...',
#    'from €175.00* '],
#   ['Gaudi in a Day Guided Private Tour', 'from €197.00* '],
#   ['Barcelona and Montserrat Helicopter Tour', 'from €299.00* '],
#   ['Private Gaudi Tour with Skip-the-Line Tickets', 'from €458.00* '],
#   ['Private Gaudi Tour in Barcelona with Sagrada Familia and Park Guell...',
#    'from €129.00* '],
#   ['Venice Private Tour', 'from €164.00* '],
#   ['Basque Towns Private Trip from Bilbao', 'from €135.00* '],
#   ['Private 8-hour excursion from Naples Cruise Port or City Hotel to...',
#    'from €100.00* '],
#   ['Discover Gaudi Private Tour', 'from €197.00* '],
#   ['Montserrat Small-Group Easy Hike with Cable Car from Barcelona',
#    'from €62.00* '],
#   ['Vatican Treasure Private Tour', 'from €85.00* '],
#   ['Tapas and Wine Walking Tour with Flamenco Experience', 'from €104.00* '],
#   ['Private Guided Tour of Costa Brava from Barcelona', 'from €180.00* '],
#   ['Private Customized Barcelona Tour by Mercedes Minibus', 'from €750.00* '],
#   ['Private Official Guide to Visit Alhambra in Granada from Malaga',
#    'from €105.00* '],
#   ['VIP Small Group Guided Tour: Girona and Costa Brava with Lunch',
#    'from €170.00* '],
#   ['Private 4-Hour Shore Excursion to Pompeii from Naples Cruise Port',
#    'from €80.00* '],
#   ['Barcelona Walking Tour with Priority Access Sagrada Familia',
#    'from €110.00* '],
#   ['Costa Brava and Girona Small Group Easy Hiking from Barcelona',
#    'from €75.60* '],
#   ['Camp Nou Stadium and Highlights of Barcelona Private Guided Tour',
#    'from €160.00* '],
#   ['Private Tour: Barcelona Full-Day Sightseeing Tour', 'from €202.50* '],
#   ['Bilbao Private Walking Tour', 'from €32.00* '],
#   ['Barcelona Balloon Rides', 'from €160.00* ']],
#  [['Poble Espanyol Entrance Ticket in Barcelona with Optional Video Guide',
#    'from €13.00* '],
#   ['Painting and Wine', 'from €35.00* '],
#   ['Palau de la Música Concerts July-December (Modernist Concert Hall...',
#    'from €12.00* '],
#   ['e-Bike tour in English', 'from €35.00* '],
#   ['Museu de la Xocolata Admission Ticket', 'from €6.00* '],
#   ['Basilica de Santa Maria del Pi Guided Tour with Tower Access',
#    'from €8.50* '],
#   ['Barcelona in One Day Sightseeing Tour', 'from €92.00* '],
#   ['Private Guided Barcelona City Tour', 'from €528.00* '],
#   ['Montserrat 7-hour Private Tour from Barcelona with Lunch',
#    'from €195.00* '],
#   ['Barcelona Highlights Small Group Half Day Tour with Hotel Pick Up',
#    'from €65.00* '],
#   ['Private Tour: Barcelona Half-Day Sightseeing Tour', 'from €111.25* '],
#   ['Barcelona Waterfront Private Sailing Small Group Tour', 'from €299.00* '],
#   ['7-Day Barcelona Attractions Pass Including La Sagrada Familia, Park...',
#    'from €85.00* '],
#   ['Girona, Figueres Small Group Tour with Dalí Museum and Hotel Pick Up',
#    'from €95.00* '],
#   ['Tarragona Half-Day Small-Group Tour with Hotel Pick Up', 'from €78.00* '],
#   ['Barcelona Private Transfer from City Centre to Cruise Terminal',
#    'from €13.34* '],
#   ['Dome Climb Tour with Reservations', 'from €45.00* '],
#   ['PortAventura Park and Ferrari Land Day Trip from Barcelona',
#    'from €68.00* '],
#   ['Tapas Walking Tour and Flamenco Show in Barcelona', 'from €55.00* '],
#   ['Flamenco Show Palau de la Música Catalana', 'from €30.00* '],
#   ['Madrid Segway City Tour', 'from €69.00* '],
#   ['Sagrada Familia Skip-the-Line Tickets and Guided Tour', 'from €34.50* '],
#   ['Barcelona City Morning Tour on Electric Bike', 'from €40.00* '],
#   ["Dinner with Stars at Fabra's Observatory", 'from €71.00* '],
#   ['Gothic Quarter Photoshoot Tour in Barcelona', 'from €45.00* '],
#   ['Welcome to Barcelona City Stroll, Jamon Tasting & Panorama',
#    'from €35.00* '],
#   ['Experience Gaudi: Create Your Own Trencadis-Style Mosaic',
#    'from €45.00* '],
#   ['Barcelona Private Walking Tour through the City of Gaudi',
#    'from €69.00* '],
#   ['Bodegas and Tapas Evening Tour', 'from €80.00* '],
#   ['Gaudí Segway Tour', 'from €59.00* ']],
#  [['Costa Brava Motorboat Tour including Water Toys', 'from €69.00* '],
#   ['Vatican Tour with Special Access to Restricted Areas', 'from €340.00* '],
#   ['Private Vatican Tour with Extended Itinerary', 'from €93.00* '],
#   ["Colosseum For Kids with Underground of San Clemente's Basilica",
#    'from €68.00* '],
#   ['Rome Safari City Tour For Kids', 'from €45.00* '],
#   ['Private Tour of Colosseum, Vatican and Trevi fountain', 'from €152.00* '],
#   ['Cordoba Private Tour from Seville', 'from €139.00* '],
#   ['Virtual reality Colosseum Private Kids Tour', 'from €97.00* '],
#   ['8-hour Private Tour Montserrat and Winery Visit from Barcelona with...',
#    'from €170.00* '],
#   ['6-Hour Private tour of Girona: GAME OF THRONES from Barcelona',
#    'from €100.00* '],
#   ['Market to Fork with Social Cooker, Yves', 'from €110.00* '],
#   ['Barcelona Private Motorboat Sailing Trips With Cava', 'from €99.00* '],
#   ['Barcelona Private Sailing Trips with Tapas', 'from €180.00* '],
#   ['GoCar Beach & Shopping', 'from €45.00* '],
#   ['Private Transfer: Barcelona to Sitges', 'from €21.70* '],
#   ['Private 8-Hour Tour to 2 wineries in Franciacorta and Bergamo from...',
#    'from €209.00* '],
#   ['Barcelona Gaudi Private Guided Tour', 'from €112.00* '],
#   ['7-Day European Tour Exploring Spain and Portugal', 'from €546.00* '],
#   ['Private Guided Tapas Tour of Barcelona', 'from €107.00* '],
#   ['Private Luxury Transfer from Palermo airport to Palermo city center',
#    'from €20.00* '],
#   ['Barcelona Scooter Rental', 'from €71.00* '],
#   ['Girona and Barcelona Highlights: Guided Day Tour', 'from €98.00* '],
#   ['Bike tour without Internet', 'from €79.00* '],
#   ['Opium Vip Night Tour', 'from €44.50* '],
#   ['Private Tour: Sitges and Wine Tasting Penedés', 'from €150.00* '],
#   ['La Casa de la Seda Private Guided Guided Tour with Glass of Cava in...',
#    'from €315.00* '],
#   ['Private Full Day Tour of Chefchaouen from Tanger', 'from €120.00* '],
#   ['Private 3-Hour Walking Tour of Florence with private official tour...',
#    'from €29.00* '],
#   ['Private 8-hour Shore Excursion from Civitavecchia to Rome',
#    'from €130.00* '],
#   ['Private 10-Hour Tour of Orvieto & Assisi from Rome', 'from €124.50* ']],
#  [['Private Day Tour of Madrid Higlights with Visits to Escorial...',
#    'from €145.00* '],
#   ['Madrid 4-Hour Private Custom Walking Tour of Los Austrias',
#    'from €38.00* '],
#   ['The Montjuïc & Panoramic tour', 'from €35.00* '],
#   ['All Barcelona Highlights tour', 'from €70.00* '],
#   ['Tapas bike tour', 'from €79.00* '],
#   ['Quest bike tour', 'from €79.00* '],
#   ['2-Hour Private Barcelona Segway Night Tour', 'from €59.00* '],
#   ['Magic Tour', 'from €49.00* '],
#   ['Barcelona Shore Excursion: Scooter Rental', 'from €38.00* '],
#   ['Montserrat Tour & Sailing Experience Small Group from Port Vell',
#    'from €114.40* '],
#   ['Outdoors small group tour of Barrio Gotico and Sagrada Familia',
#    'from €90.00* '],
#   ['Private outdoors tour of Barrio Gotico and Sagrada Familia',
#    'from €45.00* '],
#   ['Harley Davidson Ride and Sailing Small Group Experience in Barcelona',
#    'from €134.00* '],
#   ['More than a city: Barcelona Nature Walk', 'from €60.00* '],
#   ['Private 8 hour tour or shore excursion of the French Riviera from Nice',
#    'from €2,120.00* '],
#   ['Andorra Skiing and Shopping Private Day Trip from Barcelona',
#    'from €1,000.00* '],
#   ['Private 8 hour shore excursion of the French Riviera from Cannes',
#    'from €2,120.00* '],
#   ['Private 4-hour Shore Excursion of Marseille', 'from €1,300.00* '],
#   ['Pyrenees Mountains Private Day Trip from Barcelona', 'from €170.00* '],
#   ['Barcelona 360 Panoramic View: Land, Sea and Air', 'from €50.15* '],
#   ['Helicopter Flight & BCN Highlights with Sagrada Familia and Camp Nou...',
#    'from €89.60* '],
#   ['Barcelona Sagrada Familia and Park Guell for Kids and Families',
#    'from €79.00* '],
#   ['Private Priorat Wine Tour from Barcelona', 'from €350.00* '],
#   ['Modernism & Sagrada Familia with Tower Access Walking Tour',
#    'from €59.00* '],
#   ['Barcelona in a Day for Kids and Families with Sagrada Familia and...',
#    'from €119.00* '],
#   ['3-hour Barcelona Family Tour: Virtual Reality Dragon Hunters Game',
#    'from €200.00* '],
#   ['Barcelona Old City Tour for Kids and Families with Churros Stop',
#    'from €39.00* '],
#   ['la bicicleta modernista', 'from €75.00* '],
#   ['Private Montserrat, Gaudi and Modernism Day Trip from Barcelona',
#    'from €110.00* '],
#   ['Barcelona High-Speed RIB Boat Cruise', 'from €45.00* ']]]
